# %% [markdown]
# # EEG Data Processing for Parkinson's Disease Classification
#
# This notebook processes raw EEG data and creates balanced train/validation/test splits.
#
# **Dataset Information:**
# - 55 subjects total (27 Control + 28 Parkinson's)
# - 59 EEG channels
# - 500 Hz sampling rate
# - 60 seconds per subject (eyes closed resting state)
# - Pre-processed with 1 Hz high-pass filter

# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import joblib
import sys

# Add modules to path
sys.path.append(str(Path.cwd() / 'modules'))

from modules.path_module import *
from modules.processing_module import *

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## 2. Setup Paths and Parameters

# %%
# Ensure all directories exist
ensure_directories()

# Get paths
raw_path = raw_datapath()
processed_path = processed_datapath()

print(f"Raw data path: {raw_path}")
print(f"Processed data path: {processed_path}")

# Parameters
SAMPLING_RATE = 500  # Hz
SEGMENT_LENGTH = 5  # seconds
DATA_SPLIT = (0.6, 0.2, 0.2)  # Train, Val, Test
RANDOM_SEED = 42
# Out:
# ✓ Directory ready: c:\Users\KSWes\MemSNNforPD\LightCNNforPD-master\data\raw
# ✓ Directory ready: c:\Users\KSWes\MemSNNforPD\data\processed
# ✓ Directory ready: c:\Users\KSWes\MemSNNforPD\MemSNNforPD-master\results\snn
# ✓ Directory ready: c:\Users\KSWes\MemSNNforPD\MemSNNforPD-master\models
# ✓ Directory ready: c:\Users\KSWes\MemSNNforPD\MemSNNforPD-master\results
# Raw data path: c:\Users\KSWes\MemSNNforPD\LightCNNforPD-master\data\raw
# Processed data path: c:\Users\KSWes\MemSNNforPD\data\processed

# %% [markdown]
# ## 3. Load Raw Data Files

# %%
# Get all CSV files
control_files = sorted(raw_path.glob('C*.csv'))
pd_files = sorted(raw_path.glob('P*.csv'))

print(f" {len(control_files)} Control subjects")
print(f" {len(pd_files)} Parkinson's subjects")
print(f"Total: {len(control_files) + len(pd_files)} subjects")

# Combine files and create group labels
all_files = control_files + pd_files
groups = ['C'] * len(control_files) + ['P'] * len(pd_files)
# Out:
#  27 Control subjects
#  28 Parkinson's subjects
# Total: 55 subjects

# %% [markdown]
# ## 4. Load and Inspect Sample Data

# %%
# Load a sample file to check data format
sample_data = pd.read_csv(control_files[0], header=None)

print(f"Sample data shape: {sample_data.shape}")
print(f"Number of channels: {sample_data.shape[0]}")
print(f"Number of samples: {sample_data.shape[1]}")
print(f"Duration: {sample_data.shape[1] / SAMPLING_RATE} seconds")
print(f"\nData preview:")
print(sample_data.iloc[:5, :10])
# Out:
# Sample data shape: (59, 30000)
# Number of channels: 59
# Number of samples: 30000
# Duration: 60.0 seconds
#
# Data preview:
#          0       1        2         3          4        5        6        7  \
# 0 -47.9900 -67.074 -75.8000 -94.29300 -103.47000 -73.6320 -27.4870 -19.7540
# 1 -13.4880 -14.853 -11.2350  -7.95540  -10.33500 -17.9360 -20.5550 -15.2140
# 2  -2.6829   2.300   2.7462   2.36730   -2.59720  -9.8051 -13.3510  -8.3039
# 3  11.5580  15.906   8.7843  -1.41060   -7.16270  -6.4722  -5.3454  -9.8372
# 4  21.2370  29.297  12.9490  -0.12456   -0.70045  -8.2143 -16.5160   8.7196
#
#          8        9
# 0 -46.8650 -43.6390
# 1 -11.3360 -13.9010
# 2  -4.8191  -6.6064
# 3  -1.4905   3.7296
# 4  21.7960   6.7025

# %% [markdown]
# ## 5. Load All Data

# %%
# Load all EEG data
print("Loading all EEG data...")
dataset = data_load(all_files, groups, Fs=SAMPLING_RATE)

print(f"\nLoaded {len(dataset)} subjects")

# Count subjects per group
control_count = sum(1 for eeg in dataset.values() if eeg.label == 0)
pd_count = sum(1 for eeg in dataset.values() if eeg.label == 1)
# Out:
# Loading all EEG data...
#
# Loaded 55 subjects

# %% [markdown]
# ## 6. Split patients, then Segment

# %%
print("Splitting patients and segmenting data...")

train_data, val_data, test_data, patient_metadata = data_prepare_patient_level(
    dataset,
    seg_length=SEGMENT_LENGTH,
    data_split=DATA_SPLIT,
    seed=RANDOM_SEED
)
# Out:
# Splitting patients and segmenting data...
# Total patients: 55
#   Control: 27 patients
#   PD: 28 patients
#
# Patient split:
#   Train: 16 Control + 16 PD = 32 patients
#   Val:   5 Control + 5 PD = 10 patients
#   Test:  6 Control + 7 PD = 13 patients
#
# Segment counts:
#   Train: 384 segments (Control: 192, PD: 192)
#   Val:   120 segments (Control: 60, PD: 60)
#   Test:  156 segments (Control: 72, PD: 84)

# %% [markdown]
# ## 7. Save Processed Data

# %%
# Save processed data using joblib
train_path = processed_path / 'train_data.pkl'
val_path = processed_path / 'val_data.pkl'
test_path = processed_path / 'test_data.pkl'

print("Saving processed data...")
joblib.dump(train_data, train_path)
joblib.dump(val_data, val_path)
joblib.dump(test_data, test_path)

print(f"\nData saved successfully!")
print(f"  Train: {train_path}")
print(f"  Val: {val_path}")
print(f"  Test: {test_path}")
# Out:
# Saving processed data...
#
# Data saved successfully!
#   Train: c:\Users\KSWes\MemSNNforPD\data\processed\train_data.pkl
#   Val: c:\Users\KSWes\MemSNNforPD\data\processed\val_data.pkl
#   Test: c:\Users\KSWes\MemSNNforPD\data\processed\test_data.pkl

# %% [markdown]
# ## 8. Create Metadata File

# %%
# Create metadata dictionary
metadata = {
    'num_channels': train_data[0].data.shape[0],
    'sampling_rate': SAMPLING_RATE,
    'segment_length': SEGMENT_LENGTH,
    'segment_samples': train_data[0].data.shape[1],
    'data_split': DATA_SPLIT,
    'random_seed': RANDOM_SEED,
    'split_method': 'patient_level', 
    'train_size': len(train_data),
    'val_size': len(val_data),
    'test_size': len(test_data),
    'train_control': sum(1 for x in train_data if x.label == 0),
    'train_pd': sum(1 for x in train_data if x.label == 1),
    'val_control': sum(1 for x in val_data if x.label == 0),
    'val_pd': sum(1 for x in val_data if x.label == 1),
    'test_control': sum(1 for x in test_data if x.label == 0),
    'test_pd': sum(1 for x in test_data if x.label == 1),
    # Add patient-level information
    'patient_split': patient_metadata['patient_counts'],
    'patient_ids': patient_metadata['patient_ids']
}

# Save metadata
import json
metadata_path = processed_path / 'metadata.json'
with open(metadata_path, 'w') as f:
    json.dump(metadata, f, indent=4)

print("Metadata saved!")
print(json.dumps({k: v for k, v in metadata.items() if k != 'patient_ids'}, indent=2))
# Out:
# Metadata saved!
# {
#   "num_channels": 59,
#   "sampling_rate": 500,
#   "segment_length": 5,
#   "segment_samples": 2500,
#   "data_split": [
#     0.6,
#     0.2,
#     0.2
#   ],
#   "random_seed": 42,
#   "split_method": "patient_level",
#   "train_size": 384,
#   "val_size": 120,
#   "test_size": 156,
#   "train_control": 192,
#   "train_pd": 192,
#   "val_control": 60,
#   "val_pd": 60,
#   "test_control": 72,
#   "test_pd": 84,
#   "patient_split": {
#     "train_patients": 32,
#     "val_patients": 10,
#     "test_patients": 13,
#     "train_control_patients": 16,
#     "train_pd_patients": 16,
#     "val_control_patients": 5,
#     "val_pd_patients": 5,
#     "test_control_patients": 6,
#     "test_pd_patients": 7
#   }
# }
